# %% [markdown]
# # **花卷学Python**
# ---
#
# > **我年纪轻轻就学会了Python编程**
#
# ### **我们的优势：**
#
#
# | 序号 | 优势 |
# | ---- | ---- |
# | 1&emsp;&emsp;&emsp;&emsp; | **<font color="#dd0000">基于最新的Python版本（3.10），涉及到很多新的用法，如模式匹配等等</font>**&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; |
# | 2 | **<font color="#dd0000">全教程基于jupyter notebook，方便大家运行和查看</font>** |
# | 3 | **<font color="#dd0000">最终会带领大家编程完整的项目：人工智能项目</font>** |
# | 4 | **<font color="#dd0000">Python几代版本的差异</font>** |
# | 5 | **<font color="#dd0000">不只是Python，我们还需会涉及到很多：数据分析，人工智能等领域</font>** |
# | 6 | **<font color="#dd0000">教程期间涉及到很多自身工作中遇到的奇闻怪事，bug等</font>** |
#
#
# ---
#
#
# # **目录**
#
#
# **1. Python编程：简介、安装、第一个程序、IDE**
#
#    - [x] **简介**
#    - [x] **安装**
#    - [x] **第一个Python程序**
#    - [x] **Python解释器**
#    - [x] **IDE推荐：IDLE、jupyter、pycharm、VSCode**
#
#
#
# **2. Python编程：数据类型和变量**
#    - [x] **数据类型和变量**
#    - [x] **numger：数字**
#    - [x] **string：字符串 和 bytes**
#    - [x] **bool：布尔值**
#    - [x] **None：空值**
#    - [x] **list：列表**
#    - [x] **set：集合**
#    - [x] **dict：字典**
#    - [x] **tuple：元祖**
#    - [x] **不可变数据与可变数据**
#
#
#
# **3. Python编程：运算符**
#
#    - [x] **算数运算**
#    - [x] **比较运算**
#    - [x] **赋值运算**
#    - [x] **逻辑运算**
#    - [x] **位运算**
#    - [x] **成员运算**
#    - [x] **身份运算**
#    - [x] **运算符优先级**
#
#
#
# **4. Python编程：分支、循环、推导式、生成器、迭代器**
#
#    - [x] **分支**
#    - [x] **三元运算**
#    - [x] **模式匹配（3.10新用法）**
#    - [x] **循环**
#    - [x] **海象运算**
#    - [x] **推导式**
#    - [x] **生成器**
#    - [x] **迭代器**
#
#
#
# **5. Python编程：函数、装饰器、模块**
#
#    - [x] **函数**
#    - [x] **return和yield：再看生成器**
#    - [x] **局部变量和全局变量**
#    - [x] **匿名函数**
#    - [x] **内置函数**
#    - [x] **装饰器**
#
#
# **6. Python编程：面向对象编程**
#
#    - [x] **类、对象、实例**
#    - [x] **访问限制**
#    - [x] **继承和多态**
#    - [x] **类的装饰器**
#    - [x] **类的魔法方法**
#
#
# **7. Python编程：模块与包**
#
#    - [x] **模块**
#    - [x] **包**
#    - [x] **作用域**
#    - [x] **pip安装模块**
#
#
# **8. Python编程：异常与调试**
#
#    - [x] **异常**
#    - [x] **调试**
#    - [x] **单元调试**
#    - [x] **文档调试**
#
#
#
# **9. Python编程：IO编程**
#
#    - [x] **文件读写**
#    - [x] **with-as上下文管理器**
#    - [x] **StringIO和BytesIO**
#    - [x] **操作文件和目录：os.path和pathlib**
#    - [x] **序列化**
#
#
#
# **10. Python编程：线程、进程、异步**
#
#    - [x] **多线程**
#    - [x] **多进程**
#    - [x] **异步**
#
#
#
# **11. Python编程：常用内置模块**
#    - [x] **os**
#    - [x] **sys**
#    - [x] **pickle、json**
#    - [x] **time、datetime、calendar**
#    - [x] **logging**
#    - [x] **argparse**
#    - [x] **re正则表达式**
#    - [x] **base64**
#    - [x] **struct**
#    - [x] **hashlib**
#    - [x] **csv**
#    - [x] **wav**
#    - [x] **urllib**
#    - [x] **contextlib**
#    - [x] **operator**
#    - [x] **functools**
#    - [x] **itertools**
#    - [x] **collections**
#
#
#
# **12. Python编程：常用第三方模块**
#
#    - [x] **psutil**
#    - [x] **prettytable**
#    - [x] **requests**
#    - [x] **beautifulsoup**
#    - [x] **数据分析三剑客：numpy、matplotlib、pandas**
#    - [x] **jieba**
#    - [x] **pillow**
#    - [x] **opencv**
#
#
# **13. Python编程：电子邮件**
#
#    - [x] **发送邮件**
#    - [x] **收取邮件**
#
#
#
# **14. Python编程：操作数据库**
#
#    - [x] **sqlite**
#    - [x] **msyql**
#
#
#
# **15. Python编程：总结、Python版本差异**
#
#    - [x] **总结**
#    - [x] **Python版本差异**
#
#
#
# **16. PythonWeb开发：Flask**
#
# **17. PythonWeb开发：FastAPI**
#
# **18. Python人工智能开发导读：scikit-learn、tensorflow、pytorch、nlp、cv、speech**
#
# **19. Python项目实战**
